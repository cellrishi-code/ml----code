# %% [markdown]
# <a href="https://colab.research.google.com/github/cellrishi-code/ml----code/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/iphone_purchase_records.csv')

# %%
df
# Out:
#      Gender  Age  Salary  Purchase Iphone
# 0      Male   19   19000                0
# 1      Male   35   20000                0
# 2    Female   26   43000                0
# 3    Female   27   57000                0
# 4      Male   19   76000                0
# ..      ...  ...     ...              ...
# 395  Female   46   41000                1
# 396    Male   51   23000                1
# 397  Female   50   20000                1
# 398    Male   36   33000                0
# 399  Female   49   36000                1
#
# [400 rows x 4 columns]

# %%
df.drop(columns=['Gender'], inplace = True)

# %%
df
# Out:
#      Age  Salary  Purchase Iphone
# 0     19   19000                0
# 1     35   20000                0
# 2     26   43000                0
# 3     27   57000                0
# 4     19   76000                0
# ..   ...     ...              ...
# 395   46   41000                1
# 396   51   23000                1
# 397   50   20000                1
# 398   36   33000                0
# 399   49   36000                1
#
# [400 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.iloc[:,1:], df.iloc[:,0],test_size=0.2, random_state=2)

# %%
X_train.head()
# Out:
#      Salary  Purchase Iphone
# 205   47000                0
# 354   99000                1
# 3     57000                0
# 264   90000                1
# 194   89000                0

# %%
df.shape
# Out:
# (400, 3)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[-0.65924556, -0.72876641],
#        [ 0.87392651,  1.3721818 ],
#        [-0.36440478, -0.72876641],
#        [ 0.6085698 ,  1.3721818 ],
#        [ 0.57908572, -0.72876641],
#        [ 0.01888824, -0.72876641],
#        [ 2.11225779, -0.72876641],
#        [-0.30543662, -0.72876641],
#        [-0.27595254,  1.3721818 ],
#        [ 2.20071003,  1.3721818 ],
#        [ 1.0213469 ,  1.3721818 ],
#        [-1.48479975, -0.72876641],
#        [ 0.54960165,  1.3721818 ],
#        [ 1.90586924, -0.72876641],
#        [ 0.31372902, -0.72876641],
#        [-0.77718187, -0.72876641],
#        [ 0.49063349, -0.72876641],
#        [-1.51428383, -0.72876641],
#        [-0.71821372, -0.72876641],
#        [-0.57079333, -0.72876641],
#        [ 0.04837232, -0.72876641],
#        [-0.51182517, -0.72876641],
#        [-1.51428383, -0.72876641],
#        [ 0.31372902, -0.72876641],
#        [ 0.07785639, -0.72876641],
#        [-1.13099081, -0.72876641],
#        [-1.54376791, -0.72876641],
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=15)

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=15)

# %%
from sklearn.metrics import accuracy_score

y_pred = knn.predict(X_test)

accuracy_score(y_test, y_pred)
# Out:
# 0.1

# %%
scores = []

for i in range(1,100):

    knn = KNeighborsClassifier(n_neighbors=i)

    knn.fit(X_train,y_train)

    y_pred = knn.predict(X_test)

    scores.append(accuracy_score(y_test, y_pred))

# %%
import matplotlib.pyplot as plt

plt.plot(range(1,100),scores)
